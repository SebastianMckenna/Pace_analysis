# %%
import xarray as xr
import xesmf as xe
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import dask

# %%
#load model clim

# %%
MO = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/global_sst_restoring_cm000_climatology_0951-1150.nc", decode_cf=False)
PO = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/HadISST_Climatology.nc", decode_cf=False)

# %%
MO = MO.temp
PO = PO.temp

# %%
PO
# Out:
# <xarray.DataArray 'temp' (DEPTH1_1: 1, TIME: 12, GRID_Y_T: 300, GRID_X_T: 360)>
# [1296000 values with dtype=float64]
# Coordinates:
#   * TIME      (TIME) float64 15.0 44.0 73.5 104.0 ... 257.0 287.5 318.5 349.0
#   * DEPTH1_1  (DEPTH1_1) float64 0.0
#   * GRID_Y_T  (GRID_Y_T) float64 -77.88 -77.63 -77.38 ... 88.87 89.32 89.77
#   * GRID_X_T  (GRID_X_T) float64 -279.5 -278.5 -277.5 -276.5 ... 77.5 78.5 79.5
# Attributes:
#     _FillValue:     -1e+20
#     regrid_method:  conservative_normed
#     long_name:      Climatology SST restoring
#     units:          degrees K
#     valid_range:    [-10. 500.]

# %%
plt.figure(figsize = (8,4))
MO.sel(GRID_X_T=-170.0, GRID_Y_T=-2.0, method='nearest').plot(label = 'Model Clim', alpha = 0.5)
PO.sel(GRID_X_T=-170.0, GRID_Y_T=-2.0, method='nearest').plot(label = 'Detredned HadISST', alpha = 0.5)
plt.title("SST at 170E, 2S (Equatorial Pacific Ocea")

plt.legend()
