# %%
import xarray as xr
import xesmf as xe
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import dask
import cftime
import random
import glob
import matplotlib.gridspec as gs
import pint_xarray
import cf_xarray as cfxr
from eofs.xarray import Eof

# %%
import seaborn as sns

# %%
from dask.distributed import Client, LocalCluster
client = Client()
client
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43191 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:42657' processes=7 threads=14, memory=63.00 GiB>

# %%
CP_yr0 = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/time_Idealised_CP_anomaly_yr0.nc", decode_times=False)

# %%
EP_yr0 = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/time_Idealised_EP_anomaly_yr0.nc", decode_times=False)

# %%
CP_yr0_old = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/Idealised_CP_anomaly_yr0.nc", decode_times=False)

# %%
EP_yr0_old = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/Idealised_EP_anomaly_yr0.nc", decode_times=False)

# %%
ctrl_clim = xr.open_dataset("/g/data/e14/sm2435/Pacemaker/global_sst_restoring_cm000_climatology_0951-1150.nc", decode_times=False)

# %%
(CP_yr0.temp - EP_yr0_old.temp).plot(col = "TIME", col_wrap = 4)

# %%
(EP_yr0.temp)[0,0].where((EP_yr0.temp)[0,0]>-20, np.nan).plot(vmin = 20)

# %%
(EP_yr0.temp - CP_yr0.temp)[0,0].plot()

# %%
EP_yr0 = xr.open_dataset("/home/561/sm2435/cylc-run/u-df440/work/09900101/coupled/OCN_RUNDIR/INPUT/temp_sfc_restore.nc", decode_times=False)

# %%
CP_yr0 = xr.open_dataset("/home/561/sm2435/cylc-run/u-df442/work/09900101/coupled/OCN_RUNDIR/INPUT/temp_sfc_restore.nc", decode_times=False)

# %%
EP_yr0 = EP_yr0.temp
CP_yr0 = CP_yr0.temp

# %%
(EP_yr0 - ctrl_clim.temp).plot(col = "TIME", col_wrap = 4)

# %%
me = xr.open_dataset("/home/561/sm2435/cylc-run/u-df440/work/09900101/coupled/OCN_RUNDIR/INPUT/restore_mask.nc", decode_times=False)
mc = xr.open_dataset("/home/561/sm2435/cylc-run/u-df442/work/09900101/coupled/OCN_RUNDIR/INPUT/restore_mask.nc", decode_times=False)

# %%
me = me.restore_mask
mc = mc.restore_mask

# %%
(mc-mc)[0,0].plot()

# %%
EP = xr.open_dataset("/scratch/e14/sm2435/archive/df440/history/ocn/ocean_daily.nc-09901231", decode_times=False)
CP = xr.open_dataset("/scratch/e14/sm2435/archive/df442/history/ocn/ocean_daily.nc-09901231", decode_times=False)

# %%
EP = EP.sst
CP = CP.sst

# %%
(EP[1]).plot()
